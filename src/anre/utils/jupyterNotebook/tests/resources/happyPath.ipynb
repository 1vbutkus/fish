# %% [markdown]
# # Happy path test

# %%
x = 1
y = None

# %%
from anre.utils.jupyterNotebook.jupyterNotebook import JupyterNotebook  # noqa: E402

JupyterNotebook.setup_screen(interactive=False)

# %%
import matplotlib.pyplot as plt  # noqa: E402
import numpy as np  # noqa: E402
import pandas as pd  # noqa: E402

# %% [markdown]
# ## Run report

# %%
y = y if y is not None else 5
ans = x + y
ans
# Out:
# 6

# %%
sr = pd.Series([0, 1, 0, 2, 0, 3, 0, 4])

fig, ax = plt.subplots()
sr.plot(title='Test graph')
None

# %%
df = pd.DataFrame({'x1': sr, 'x2': np.log(1 + sr), 'x3': np.exp(sr)})
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_00ce3_row0_col0, #T_00ce3_row1_col1, #T_00ce3_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_00ce3_row0_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_00ce3_row0_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_00ce3_row1_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_00ce3_row1_col2, #T_00ce3_row2_col0, #T_00ce3_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00ce3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00ce3_level0_col0" class="col_heading level0 col0" >x1</th>
#       <th id="T_00ce3_level0_col1" class="col_heading level0 col1" >x2</th>
#       <th id="T_00ce3_level0_col2" class="col_heading level0 col2" >x3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00ce3_level0_row0" class="row_heading level0 row0" >x1</th>
#       <td id="T_00ce3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_00ce3_row0_col1" class="data row0 col1" >0.982155</td>
#       <td id="T_00ce3_row0_col2" class="data row0 col2" >0.891501</td>
#     </tr>
#     <tr>
#       <th id="T_00ce3_level0_row1" class="row_heading level0 row1" >x2</th>
#       <td id="T_00ce3_row1_col0" class="data row1 col0" >0.982155</td>
#       <td id="T_00ce3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_00ce3_row1_col2" class="data row1 col2" >0.800608</td>
#     </tr>
#     <tr>
#       <th id="T_00ce3_level0_row2" class="row_heading level0 row2" >x3</th>
#       <td id="T_00ce3_row2_col0" class="data row2 col0" >0.891501</td>
#       <td id="T_00ce3_row2_col1" class="data row2 col1" >0.800608</td>
#       <td id="T_00ce3_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
